# %%
import pandas as pd

# %%
data = pd.read_excel('shanipar.xlsx')

# %%
import pandas as pd
import numpy as np

# age_group1: WHO-style grouping
conditions1 = [
    (data["age"] >= 18) & (data["age"] <= 44),
    (data["age"] >= 45) & (data["age"] <= 59),
    (data["age"] >= 60)
]
choices1 = ["young", "middle", "old"]

data["age_group1"] = np.select(conditions1, choices1, default=np.nan)

# age_group2: refined grouping
conditions2 = [
    (data["age"] >= 18) & (data["age"] <= 25),
    (data["age"] >= 26) & (data["age"] <= 44),
    (data["age"] >= 45) & (data["age"] <= 59),
    (data["age"] >= 60)
]
choices2 = ["emerging_adult", "young_adult", "middle", "old"]

data["age_group2"] = np.select(conditions2, choices2, default=np.nan)

# %%
import numpy as np

conditions = [
    (data["bmi"] < 18.5),
    (data["bmi"] >= 18.5) & (data["bmi"] < 25),
    (data["bmi"] >= 25) & (data["bmi"] < 30),
    (data["bmi"] >= 30)
]

choices = [
    "underweight",
    "normal",
    "overweight",
    "obese"
]

data["bmi_category"] = np.select(conditions, choices, default=np.nan)

# %%
import pandas as pd

# --- age_group1 ---
age_group1_categories = ["young", "middle", "old"]
data["age_group1"] = pd.Categorical(
    data["age_group1"], 
    categories=age_group1_categories, 
    ordered=True
)
data["age_group1_num"] = data["age_group1"].cat.codes + 1   # 1-based numbering

# --- age_group2 ---
age_group2_categories = ["young adult", "early adult", "middle", "old"]
data["age_group2"] = pd.Categorical(
    data["age_group2"], 
    categories=age_group2_categories, 
    ordered=True
)
data["age_group2_num"] = data["age_group2"].cat.codes + 1

# --- bmi_category ---
bmi_categories = ["underweight", "normal", "overweight", "obese"]
data["bmi_category"] = pd.Categorical(
    data["bmi_category"], 
    categories=bmi_categories, 
    ordered=True
)
data["bmi_category_num"] = data["bmi_category"].cat.codes + 1

# %%
import re

# Step 1: Extract only the issues (before the first comma in each segment)
def extract_issues(cell):
    if pd.isna(cell):
        return []
    parts = [seg.split(",")[0].strip() for seg in cell.split(";")]
    return parts

data["current_issues_list"] = data["possibleHealthIssuesCurrent"].apply(extract_issues)


# Step 2: Clean issue names for column use
def clean_name(name):
    name = name.lower().strip()
    name = re.sub(r"[^0-9a-zA-Z]+", "_", name)   # replace non-alphanumeric with underscore
    name = re.sub(r"_+", "_", name).strip("_")   # collapse multiple underscores
    return name

# Step 3: Get all unique cleaned issues
all_issues = sorted({clean_name(issue) for issues in data["current_issues_list"] for issue in issues})

# Step 4: Create 1/0 columns for each issue
for issue in all_issues:
    data[issue] = data["current_issues_list"].apply(lambda x: 1 if issue in [clean_name(i) for i in x] else 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13864\99387105.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[issue] = data["issues_list"].apply(lambda x: 1 if issue in [clean_name(i) for i in x] else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13864\99387105.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[issue] = data["issues_list"].apply(lambda x: 1 if issue in [clean_name(i) for i in x] else 0)
# ...

# %%
data.columns.to_list()
# Out:
# ['user_id',
#  'full_name',
#  'phone_number',
#  'onboarding_date',
#  'onboarding_time',
#  'language',
#  'gender',
#  'date_of_birth',
#  'age',
#  'height',
#  'weight',
#  'bmi',
#  'prakruti',
#  'vikruti',
#  'pulse_rate',
#  'remark',
#  'rhythm',
#  'toxin_score',
#  'immunity_score',
#  'digestion_score',
#  'hyperthinking_score',
#  'stress_score',
#  'hydration_score',
#  'flexibility_score',
#  'possibleHealthIssuesCurrent',
#  'possibleHealthIssuesFuture',
#  'strongOrgans',
#  'weakOrgans',
#  'atRiskOrgans',
#  'age_group1',
#  'age_group2',
#  'bmi_category',
#  'age_group1_num',
#  'age_group2_num',
#  'bmi_category_num',
#  'issues_list',
#  'acid_reflux',
#  'acidity',
#  'acidity_heartburn',
#  'anxiety',
#  'anxiety_and_hyperthinking',
#  'anxiety_and_restlessness',
#  'anxiety_and_restlessness_due_to_vata_aggravation',
#  'anxiety_and_sleep_disturbances_stress_and_hyperthinking',
#  'anxiety_overthinking',
#  'bloating',
#  'bloating_and_gas',
# ...

# %%
# # mapping: original column name -> list of canonical group(s)
# orig_to_canonical = {
#  'acid_reflux': ['acid_reflux'],
#  'acidity': ['acid_reflux'],
#  'acidity_heartburn': ['acid_reflux'],
#  'anxiety': ['anxiety'],
#  'anxiety_and_hyperthinking': ['anxiety'],
#  'anxiety_and_restlessness': ['anxiety'],
#  'anxiety_and_restlessness_due_to_vata_aggravation': ['anxiety','dosha_imbalance'],
#  'anxiety_and_sleep_disturbances_stress_and_hyperthinking': ['anxiety','sleep_issues','stress'],
#  'anxiety_overthinking': ['anxiety'],
#  'bloating': ['digestive_issues'],
#  'bloating_and_gas': ['digestive_issues'],
#  'bloating_and_heaviness': ['digestive_issues','fatigue_low_energy'],
#  'constipation': ['digestive_issues'],
#  'digestive_acidity': ['digestive_issues', 'acid_reflux'],
#  'digestive_discomfort': ['digestive_issues'],
#  'digestive_irregularities': ['digestive_issues'],
#  'digestive_irregularities_like_bloating_and_constipation': ['digestive_issues'],
#  'digestive_irregularities_like_bloating_and_gas': ['digestive_issues'],
#  'digestive_irregularities_like_bloating_and_irregular_bowel_movements': ['digestive_issues'],
#  'digestive_irregularities_like_bloating_or_constipation': ['digestive_issues'],
#  'digestive_irregularities_like_gas_and_bloating': ['digestive_issues'],
#  'digestive_irregularities_such_as_bloating_and_irregular_bowel_movements': ['digestive_issues'],
#  'digestive_irregularity': ['digestive_issues'],
#  'digestive_issues_like_bloating': ['digestive_issues'],
#  'digestive_issues_like_bloating_and_irregular_bowel_movements': ['digestive_issues'],
#  'digestive_sluggishness_and_bloating': ['digestive_issues'],
#  'digestive_variability': ['digestive_issues'],
#  'dry_skin': ['skin_issues'],
#  'elevated_heart_rate': ['elevated_pulse'],
#  'elevated_pulse_rate': ['elevated_pulse'],
#  'fatigue': ['fatigue_low_energy'],
#  'fatigue_and_erratic_energy_levels': ['fatigue_low_energy'],
#  'fatigue_and_fluctuating_energy': ['fatigue_low_energy'],
#  'fatigue_due_to_fluctuating_energy_levels': ['fatigue_low_energy'],
#  'fatigue_or_energy_fluctuations_pitta_vata_vikruti': ['fatigue_low_energy','dosha_imbalance'],
#  'fatty_liver': ['metabolic_conditions'],
#  'feeling_heavy': ['fatigue_low_energy'],
#  'feeling_of_heaviness_after_meals_kapha_imbalance': ['digestive_issues','dosha_imbalance'],
#  'feeling_of_heaviness_or_sluggishness': ['fatigue_low_energy'],
#  'fluctuating_energy': ['fatigue_low_energy'],
#  'fluctuating_energy_levels': ['fatigue_low_energy'],
#  'frequent_colds': ['immunity_issues'],
#  'heartburn': ['acid_reflux'],
#  'high_cholesterol': ['metabolic_conditions'],
#  'high_pulse_rate': ['elevated_pulse'],
#  'high_stress': ['stress'],
#  'hormonal_imbalance': ['metabolic_conditions'],
#  'hyperacidity': ['acid_reflux'],
#  'hypertension': ['hypertension'],
#  'hypertension_elevated_pulse_rate_and_potential_kapha_influence_on_circulation': ['hypertension','elevated_pulse','dosha_imbalance'],
#  'hyperthinking': ['anxiety'],
#  'hyperthyroidism': ['thyroid_issues'],
#  'hypothyroidism': ['thyroid_issues'],
#  'increased_mucus_production': ['respiratory_issues'],
#  'increased_pulse_rate': ['elevated_pulse'],
#  'indigestion': ['digestive_issues'],
#  'indigestion_and_bloating': ['digestive_issues'],
#  'inflammation': ['inflammation'],
#  'irregular_appetite': ['appetite_issues'],
#  'irregular_bowel_movements': ['digestive_issues'],
#  'irregular_digestion': ['digestive_issues'],
#  'irregular_digestion_and_bloating': ['digestive_issues'],
#  'irregular_energy_levels': ['fatigue_low_energy'],
#  'irregular_heart_rhythm': ['cardiac_irregularity'],
#  'irregular_heartbeat': ['cardiac_irregularity'],
#  'irregular_pulse': ['cardiac_irregularity'],
#  'irregular_pulse_and_potential_fatigue': ['cardiac_irregularity','fatigue_low_energy'],
#  'irregular_pulse_rhythm': ['cardiac_irregularity'],
#  'irritability': ['irritability'],
#  'joint_discomfort': ['joint_issues'],
#  'joint_pain': ['joint_issues'],
#  'joint_pain_and_stiffness': ['joint_issues'],
#  'joint_stiffness': ['joint_issues'],
#  'joint_stiffness_and_cracking': ['joint_issues'],
#  'joint_stiffness_and_dryness': ['joint_issues','skin_issues'],
#  'joint_stiffness_and_occasional_pain': ['joint_issues'],
#  'joint_stiffness_and_pain_low_flexibility_and_vata_aggravation': ['joint_issues','dosha_imbalance'],
#  'joint_stiffness_or_cracking': ['joint_issues'],
#  'joint_stiffness_or_discomfort': ['joint_issues'],
#  'kapha_pitta_imbalance': ['dosha_imbalance'],
#  'lethargy': ['fatigue_low_energy'],
#  'low_digestion': ['digestive_issues'],
#  'low_energy': ['fatigue_low_energy'],
#  'low_flexibility': ['joint_issues'],
#  'low_hydration': ['hydration_issues'],
#  'low_hydration_levels': ['hydration_issues'],
#  'low_immunity': ['immunity_issues'],
#  'medium_digestion': ['digestive_issues'],
#  'medium_hydration': ['hydration_issues'],
#  'medium_hyperthinking': ['anxiety'],
#  'medium_stress': ['stress'],
#  'medium_stress_and_hyperthinking': ['stress','anxiety'],
#  'medium_stress_and_hyperthinking_impacting_mental_clarity': ['stress','anxiety'],
#  'medium_stress_levels': ['stress'],
#  'medium_toxin': ['toxin_accumulation'],
#  'mental_fatigue': ['fatigue_low_energy'],
#  'mental_fatigue_or_irritability': ['fatigue_low_energy','irritability'],
#  'mental_restlessness': ['anxiety'],
#  'mild_digestive_discomfort': ['digestive_issues'],
#  'moderate_hydration_levels_affecting_skin_health_and_overall_bodily_functions': ['hydration_issues','skin_issues'],
#  'moderate_stress': ['stress'],
#  'moderate_stress_and_hyperthinking_aggravating_factors': ['stress','anxiety'],
#  'moderate_stress_and_hyperthinking_impacting_mental_peace_and_sleep_quality': ['stress','anxiety','sleep_issues'],
#  'moderate_toxin_accumulation': ['toxin_accumulation'],
#  'obesity': ['obesity_weight'],
#  'occasional_acidity': ['acid_reflux'],
#  'occasional_anxiety': ['anxiety'],
#  'occasional_digestive_discomfort': ['digestive_issues'],
#  'occasional_dry_skin_patches': ['skin_issues'],
#  'occasional_irritability': ['irritability'],
#  'occasional_irritability_and_impatience': ['irritability'],
#  'occasional_irritability_and_intensity': ['irritability'],
#  'occasional_sluggishness_or_heaviness': ['fatigue_low_energy'],
#  'overthinking_and_occasional_irritability': ['anxiety','irritability'],
#  'pcod_pcos': ['metabolic_conditions'],
#  'pitta_kapha_imbalance_leading_to_excess_heat_and_mucus': ['dosha_imbalance'],
#  'potential_for_acidity_and_digestive_discomfort': ['acid_reflux','digestive_issues'],
#  'potential_for_acidity_and_heartburn': ['acid_reflux'],
#  'potential_for_burnout': ['stress','fatigue_low_energy'],
#  'potential_for_skin_dryness_or_inflammation': ['skin_issues'],
#  'potential_for_skin_inflammation': ['skin_issues'],
#  'potential_for_skin_issues_due_to_pitta_kapha_imbalance': ['skin_issues','dosha_imbalance'],
#  'potential_for_sluggishness_or_reduced_energy': ['fatigue_low_energy'],
#  'restlessness': ['anxiety'],
#  'restlessness_and_scattered_thoughts': ['anxiety'],
#  'skin_dryness': ['skin_issues'],
#  'skin_dryness_and_joint_discomfort': ['skin_issues','joint_issues'],
#  'skin_dryness_due_to_vata_influence': ['skin_issues','dosha_imbalance'],
#  'skin_inflammation': ['skin_issues'],
#  'skin_inflammation_or_acne': ['skin_issues'],
#  'skin_inflammation_or_redness': ['skin_issues'],
#  'skin_irritation': ['skin_issues'],
#  'skin_issues': ['skin_issues'],
#  'skin_issues_acne_redness': ['skin_issues'],
#  'skin_issues_e_g': ['skin_issues'],
#  'skin_issues_like_oiliness_or_occasional_breakouts': ['skin_issues'],
#  'skin_redness': ['skin_issues'],
#  'skin_redness_or_inflammation_pitta_imbalance': ['skin_issues','dosha_imbalance'],
#  'skin_redness_or_mild_rashes': ['skin_issues'],
#  'skin_related_issues': ['skin_issues'],
#  'skin_related_issues_dryness': ['skin_issues'],
#  'skin_related_issues_dryness_inflammation': ['skin_issues'],
#  'skin_related_issues_dryness_redness': ['skin_issues'],
#  'skin_related_issues_e_g': ['skin_issues'],
#  'skin_sensitivity': ['skin_issues'],
#  'skin_sensitivity_and_tendency_towards_redness_or_irritation': ['skin_issues'],
#  'sleep_disturbances': ['sleep_issues'],
#  'sleep_disturbances_and_restlessness': ['sleep_issues','anxiety'],
#  'sleep_disturbances_vata_imbalance': ['sleep_issues','dosha_imbalance'],
#  'sleep_issues': ['sleep_issues'],
#  'slightly_elevated_pulse_rate': ['elevated_pulse'],
#  'sluggish_digestion': ['digestive_issues'],
#  'sluggish_digestion_and_potential_bloating_from_kapha_imbalance': ['digestive_issues','dosha_imbalance'],
#  'sluggish_elimination': ['digestive_issues'],
#  'sluggishness': ['fatigue_low_energy'],
#  'stress': ['stress'],
#  'tachycardia': ['elevated_pulse'],
#  'tendency_towards_acidity_or_bloating': ['digestive_issues'],
#  'tendency_towards_constipation_or_irregular_bowel_movements': ['digestive_issues'],
#  'the_combination_of_kapha_pitta_vikruti': ['dosha_imbalance'],
#  'type_2_diabetes': ['metabolic_conditions'],
#  'variable_digestion': ['digestive_issues'],
#  'variable_energy': ['fatigue_low_energy'],
#  'variable_energy_levels': ['fatigue_low_energy'],
#  'vata_kapha_imbalance': ['dosha_imbalance'],
#  'vata_vikruti': ['dosha_imbalance'],
#  'weight_gain': ['obesity_weight']
# }
orig_to_canonical = {
    # Acid reflux & related
    'acid_reflux': ['acid_reflux'],
    'acidity': ['acid_reflux'],
    'acidity_heartburn': ['acid_reflux'],
    'heartburn': ['acid_reflux'],
    'digestive_acidity': ['acid_reflux'],
    'hyperacidity': ['acid_reflux'],
    'occasional_acidity': ['acid_reflux'],
    'potential_for_acidity_and_digestive_discomfort': ['acid_reflux', 'indigestion'],
    'potential_for_acidity_and_heartburn': ['acid_reflux'],

    # Anxiety, restlessness, overthinking
    'anxiety': ['anxiety'],
    'anxiety_and_hyperthinking': ['anxiety', 'overthinking'],
    'anxiety_and_restlessness': ['anxiety', 'restlessness'],
    'anxiety_and_restlessness_due_to_vata_aggravation': ['anxiety', 'restlessness', 'dosha_imbalance'],
    'anxiety_and_sleep_disturbances_stress_and_hyperthinking': ['anxiety', 'sleep_issues', 'stress', 'overthinking'],
    'anxiety_overthinking': ['anxiety', 'overthinking'],
    'hyperthinking': ['overthinking'],
    'hyperthinking': ['overthinking'],
    'mental_restlessness': ['restlessness'],
    'occasional_anxiety': ['anxiety'],
    'overthinking_and_occasional_irritability': ['overthinking', 'irritability'],
    'restlessness': ['restlessness'],
    'restlessness_and_scattered_thoughts': ['restlessness'],

    # Digestive issues
    'bloating': ['bloating'],
    'bloating_and_gas': ['bloating'],
    'bloating_and_heaviness': ['bloating', 'fatigue_physical'],
    'constipation': ['constipation'],
    'indigestion': ['indigestion'],
    'indigestion_and_bloating': ['indigestion', 'bloating'],
    'sluggish_digestion': ['indigestion'],
    'sluggish_digestion_and_potential_bloating_from_kapha_imbalance': ['indigestion', 'bloating', 'dosha_imbalance'],
    'sluggish_elimination': ['constipation'],
    'low_digestion': ['indigestion'],
    'mild_digestive_discomfort': ['indigestion'],
    'occasional_digestive_discomfort': ['indigestion'],
    'digestive_discomfort': ['indigestion'],
    'digestive_irregularities': ['indigestion'],
    'digestive_irregularities_like_bloating_and_constipation': ['bloating', 'constipation'],
    'digestive_irregularities_like_bloating_and_gas': ['bloating'],
    'digestive_irregularities_like_bloating_and_irregular_bowel_movements': ['bloating', 'constipation'],
    'digestive_irregularities_like_bloating_or_constipation': ['bloating', 'constipation'],
    'digestive_irregularities_like_gas_and_bloating': ['bloating'],
    'digestive_irregularities_such_as_bloating_and_irregular_bowel_movements': ['bloating', 'constipation'],
    'digestive_irregularity': ['indigestion'],
    'digestive_issues_like_bloating': ['bloating'],
    'digestive_issues_like_bloating_and_irregular_bowel_movements': ['bloating', 'constipation'],
    'digestive_sluggishness_and_bloating': ['indigestion', 'bloating'],
    'digestive_variability': ['indigestion'],
    'irregular_bowel_movements': ['constipation'],
    'irregular_digestion': ['indigestion'],
    'irregular_digestion_and_bloating': ['indigestion', 'bloating'],
    'sluggishness': ['fatigue_physical'],
    'tendency_towards_acidity_or_bloating': ['acid_reflux', 'bloating'],
    'tendency_towards_constipation_or_irregular_bowel_movements': ['constipation'],
    'variable_digestion': ['indigestion'],

    # Appetite
    'irregular_appetite': ['appetite_issues'],

    # Pulse-related
    'elevated_heart_rate': ['elevated_pulse'],
    'elevated_pulse_rate': ['elevated_pulse'],
    'high_pulse_rate': ['elevated_pulse'],
    'increased_pulse_rate': ['elevated_pulse'],
    'slightly_elevated_pulse_rate': ['elevated_pulse'],
    'tachycardia': ['elevated_pulse'],

    # Cardiac irregularities
    'irregular_heart_rhythm': ['cardiac_irregularity'],
    'irregular_heartbeat': ['cardiac_irregularity'],
    'irregular_pulse': ['cardiac_irregularity'],
    'irregular_pulse_and_potential_fatigue': ['cardiac_irregularity', 'fatigue_physical'],
    'irregular_pulse_rhythm': ['cardiac_irregularity'],

    # Fatigue/energy
    'fatigue': ['fatigue_physical'],
    'fatigue_and_erratic_energy_levels': ['fatigue_fluctuating'],
    'fatigue_and_fluctuating_energy': ['fatigue_fluctuating'],
    'fatigue_due_to_fluctuating_energy_levels': ['fatigue_fluctuating'],
    'fatigue_or_energy_fluctuations_pitta_vata_vikruti': ['fatigue_fluctuating', 'dosha_imbalance'],
    'feeling_heavy': ['fatigue_physical'],
    'feeling_of_heaviness_after_meals_kapha_imbalance': ['fatigue_physical', 'bloating', 'dosha_imbalance'],
    'feeling_of_heaviness_or_sluggishness': ['fatigue_physical'],
    'fluctuating_energy': ['fatigue_fluctuating'],
    'fluctuating_energy_levels': ['fatigue_fluctuating'],
    'lethargy': ['fatigue_physical'],
    'low_energy': ['fatigue_physical'],
    'mental_fatigue': ['fatigue_mental'],
    'mental_fatigue_or_irritability': ['fatigue_mental', 'irritability'],
    'occasional_sluggishness_or_heaviness': ['fatigue_physical'],
    'potential_for_burnout': ['fatigue_mental'],
    'potential_for_sluggishness_or_reduced_energy': ['fatigue_physical'],
    'variable_energy': ['fatigue_fluctuating'],
    'variable_energy_levels': ['fatigue_fluctuating'],

    # Immunity
    'frequent_colds': ['immunity_issues'],
    'low_immunity': ['immunity_issues'],

    # Hydration
    'low_hydration': ['hydration_issues'],
    'low_hydration_levels': ['hydration_issues'],
    'medium_hydration': ['hydration_issues'],
    'moderate_hydration_levels_affecting_skin_health_and_overall_bodily_functions': ['hydration_issues', 'skin_dryness'],

    # Hypertension
    'hypertension': ['hypertension'],
    'hypertension_elevated_pulse_rate_and_potential_kapha_influence_on_circulation': ['hypertension', 'elevated_pulse', 'dosha_imbalance'],

    # Metabolic (split out specifics)
    'fatty_liver': ['fatty_liver'],
    'high_cholesterol': ['high_cholesterol'],
    'hormonal_imbalance': ['hormonal_imbalance'],
    'pcod_pcos': ['pcod_pcos'],
    'type_2_diabetes': ['type_2_diabetes'],

    # Obesity/weight
    'obesity': ['obesity_weight'],
    'weight_gain': ['obesity_weight'],

    # Skin
    'dry_skin': ['skin_dryness'],
    'occasional_dry_skin_patches': ['skin_dryness'],
    'skin_dryness': ['skin_dryness'],
    'skin_dryness_and_joint_discomfort': ['skin_dryness', 'joint_discomfort'],
    'skin_dryness_due_to_vata_influence': ['skin_dryness', 'dosha_imbalance'],
    'skin_inflammation': ['skin_inflammation'],
    'skin_inflammation_or_acne': ['skin_inflammation'],
    'skin_inflammation_or_redness': ['skin_inflammation'],
    'skin_irritation': ['skin_sensitivity'],
    'skin_issues': ['skin_issues'],
    'skin_issues_acne_redness': ['skin_inflammation'],
    'skin_issues_e_g': ['skin_issues'],
    'skin_issues_like_oiliness_or_occasional_breakouts': ['skin_issues'],
    'skin_redness': ['skin_inflammation'],
    'skin_redness_or_inflammation_pitta_imbalance': ['skin_inflammation', 'dosha_imbalance'],
    'skin_redness_or_mild_rashes': ['skin_inflammation'],
    'skin_related_issues': ['skin_issues'],
    'skin_related_issues_dryness': ['skin_dryness'],
    'skin_related_issues_dryness_inflammation': ['skin_dryness', 'skin_inflammation'],
    'skin_related_issues_dryness_redness': ['skin_dryness', 'skin_inflammation'],
    'skin_related_issues_e_g': ['skin_issues'],
    'skin_sensitivity': ['skin_sensitivity'],
    'skin_sensitivity_and_tendency_towards_redness_or_irritation': ['skin_sensitivity', 'skin_inflammation'],

    # Sleep
    'sleep_disturbances': ['sleep_issues'],
    'sleep_disturbances_and_restlessness': ['sleep_issues', 'restlessness'],
    'sleep_disturbances_vata_imbalance': ['sleep_issues', 'dosha_imbalance'],
    'sleep_issues': ['sleep_issues'],

    # Stress
    'high_stress': ['stress'],
    'medium_stress': ['stress'],
    'medium_stress_and_hyperthinking': ['stress', 'overthinking'],
    'medium_stress_and_hyperthinking_impacting_mental_clarity': ['stress', 'overthinking'],
    'medium_stress_levels': ['stress'],
    'moderate_stress': ['stress'],
    'moderate_stress_and_hyperthinking_aggravating_factors': ['stress', 'overthinking'],
    'moderate_stress_and_hyperthinking_impacting_mental_peace_and_sleep_quality': ['stress', 'overthinking', 'sleep_issues'],
    'stress': ['stress'],

    # Inflammation
    'inflammation': ['inflammation'],

    # Irritability
    'irritability': ['irritability'],
    'occasional_irritability': ['irritability'],
    'occasional_irritability_and_impatience': ['irritability'],
    'occasional_irritability_and_intensity': ['irritability'],

    # Joints
    'joint_discomfort': ['joint_pain'],
    'joint_pain': ['joint_pain'],
    'joint_pain_and_stiffness': ['joint_pain'],
    'joint_stiffness': ['joint_pain'],
    'joint_stiffness_and_cracking': ['joint_pain'],
    'joint_stiffness_and_dryness': ['joint_pain', 'skin_dryness'],
    'joint_stiffness_and_occasional_pain': ['joint_pain'],
    'joint_stiffness_and_pain_low_flexibility_and_vata_aggravation': ['joint_pain', 'dosha_imbalance'],
    'joint_stiffness_or_cracking': ['joint_pain'],
    'joint_stiffness_or_discomfort': ['joint_pain'],
    'low_flexibility': ['joint_pain'],

    # Thyroid
    'hyperthyroidism': ['hyperthyroid'],
    'hypothyroidism': ['hypothyroid'],

    # Respiratory
    'increased_mucus_production': ['respiratory_issues'],

    # Toxins
    'medium_toxin': ['toxin_accumulation'],
    'moderate_toxin_accumulation': ['toxin_accumulation'],

    # Dosha imbalance
    'fatigue_or_energy_fluctuations_pitta_vata_vikruti': ['fatigue_fluctuating', 'dosha_imbalance'],
    'kapha_pitta_imbalance': ['dosha_imbalance'],
    'pitta_kapha_imbalance_leading_to_excess_heat_and_mucus': ['mucus'],
    'skin_dryness_due_to_vata_influence': ['skin_dryness', 'dosha_imbalance'],
    'skin_redness_or_inflammation_pitta_imbalance': ['skin_inflammation'],
    'sleep_disturbances_vata_imbalance': ['sleep_issues', 'dosha_imbalance'],
    'sluggish_digestion_and_potential_bloating_from_kapha_imbalance': ['indigestion', 'bloating', 'dosha_imbalance'],
    'the_combination_of_kapha_pitta_vikruti': ['dosha_imbalance'],
    'vata_kapha_imbalance': ['dosha_imbalance'],
    'vata_vikruti': ['dosha_imbalance']
}

# %%
import pandas as pd

# --- Step 5: Collapse to canonical categories efficiently ---

# Add unique row id BEFORE melt
data = data.copy()  # avoids fragmentation warnings
data['_row'] = range(len(data))

# Melt the wide issue columns into long format
df_long = data.melt(
    id_vars=['_row', 'issues_list'], 
    value_vars=list(orig_to_canonical.keys()),  # only mapped issue columns
    var_name='original', 
    value_name='flag'
)

# Keep only rows where the flag is 1 (issue present)
df_long = df_long[df_long['flag'] == 1].drop(columns='flag')

# Map each original issue to one or more canonical categories
df_long['canonical'] = df_long['original'].map(orig_to_canonical)

# Explode because some originals map to multiple canonical categories
df_long = df_long.explode('canonical')

# --- Step 6: Build canonical one-hot columns with crosstab ---
df_flags = pd.crosstab(df_long['_row'], df_long['canonical'])

# Ensure all canonical names exist as columns (even if all 0)
all_canonicals = sorted({c for v in orig_to_canonical.values() for c in v})
df_flags = df_flags.reindex(columns=all_canonicals, fill_value=0)

# --- Step 7: Drop raw one-hot issue columns ---
data = data.drop(columns=[c for c in all_issues if c in data.columns])

# Merge back canonical flags
data = data.join(df_flags.astype(int))

# --- Optional cleanup ---
data.drop(columns=['_row'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       1 import pandas as pd
#       3 # --- Step 5: Collapse to canonical categories efficiently ---
#       4
#       5 # Add unique row id BEFORE melt
# ----> 6 data = data.copy()  # avoids fragmentation warnings
#       7 data['_row'] = range(len(data))
#       9 # Melt the wide issue columns into long format
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# Save dataframe to Excel
output_file = "data_output1.xlsx"
data.to_excel(output_file, index=False)

print(f"Dataframe saved as {output_file}")
# Out:
# Dataframe saved as data_output1.xlsx

# %%
import re

# Step 1: Extract only the issues (before the first comma in each segment)
def extract_issues(cell):
    if pd.isna(cell):
        return []
    parts = [seg.split(",")[0].strip() for seg in cell.split(";")]
    return parts

data["future_issues_list"] = data["possibleHealthIssuesFuture"].apply(extract_issues)


# Step 2: Clean issue names for column use
def clean_name(name):
    name = name.lower().strip()
    name = re.sub(r"[^0-9a-zA-Z]+", "_", name)   # replace non-alphanumeric with underscore
    name = re.sub(r"_+", "_", name).strip("_")   # collapse multiple underscores
    return name

# Step 3: Get all unique cleaned issues
all_future_issues = sorted({clean_name(issue) for issues in data["future_issues_list"] for issue in issues})

# Step 4: Create 1/0 columns for each issue
for issue in all_future_issues:
    data[issue] = data["future_issues_list"].apply(lambda x: 1 if issue in [clean_name(i) for i in x] else 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13864\1484426772.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[issue] = data["future_issues_list"].apply(lambda x: 1 if issue in [clean_name(i) for i in x] else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13864\1484426772.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[issue] = data["future_issues_list"].apply(lambda x: 1 if issue in [clean_name(i) for i in x] else 0)
# ...

# %%
data.columns.to_list()
# Out:
# ['user_id',
#  'full_name',
#  'phone_number',
#  'onboarding_date',
#  'onboarding_time',
#  'language',
#  'gender',
#  'date_of_birth',
#  'age',
#  'height',
#  'weight',
#  'bmi',
#  'prakruti',
#  'vikruti',
#  'pulse_rate',
#  'remark',
#  'rhythm',
#  'toxin_score',
#  'immunity_score',
#  'digestion_score',
#  'hyperthinking_score',
#  'stress_score',
#  'hydration_score',
#  'flexibility_score',
#  'possibleHealthIssuesCurrent',
#  'possibleHealthIssuesFuture',
#  'strongOrgans',
#  'weakOrgans',
#  'atRiskOrgans',
#  'age_group1',
#  'age_group2',
#  'bmi_category',
#  'age_group1_num',
#  'age_group2_num',
#  'bmi_category_num',
#  'issues_list',
#  'acid_reflux',
#  'anxiety',
#  'appetite_issues',
#  'cardiac_irregularity',
#  'digestive_issues',
#  'dosha_imbalance',
#  'elevated_pulse',
#  'fatigue_low_energy',
#  'hydration_issues',
#  'hypertension',
#  'immunity_issues',
#  'inflammation',
#  'irritability',
#  'joint_issues',
#  'metabolic_conditions',
# ...

# %%
orig_to_canonical_ft = {
 'acid_reflux': ['ft_acid_reflux', 'ft_digestive_issues'],
 'acid_reflux_or_hyperacidity': ['ft_acid_reflux', 'ft_digestive_issues'],
 'anxiety': ['ft_anxiety'],
 'anxiety_and_hyperthinking': ['ft_anxiety'],
 'anxiety_and_restlessness': ['ft_anxiety'],
 'anxiety_and_sleep_disturbances': ['ft_anxiety', 'ft_sleep_issues'],
 'anxiety_or_insomnia': ['ft_anxiety', 'ft_sleep_issues'],
 'bloating': ['ft_digestive_issues'],
 'constipation': ['ft_digestive_issues'],
 'depression': ['ft_mental_health'],
 'digestive_discomfort': ['ft_digestive_issues'],
 'digestive_discomfort_if_pitta_imbalance_increases': ['ft_digestive_issues', 'ft_dosha_imbalance'],
 'digestive_disorders': ['ft_digestive_issues'],
 'digestive_disorders_like_acid_reflux': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_disorders_like_acid_reflux_or_bloating': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_disorders_like_gerd_or_ulcers': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_disorders_like_hyperacidity_or_bloating': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_disorders_like_ibs': ['ft_digestive_issues'],
 'digestive_disorders_like_ibs_vata_and_pitta_imbalance': ['ft_digestive_issues', 'ft_dosha_imbalance'],
 'digestive_disorders_like_ibs_vata_pitta_imbalance': ['ft_digestive_issues', 'ft_dosha_imbalance'],
 'digestive_disorders_like_indigestion_or_constipation': ['ft_digestive_issues'],
 'digestive_disturbances': ['ft_digestive_issues'],
 'digestive_disturbances_like_bloating_and_gas': ['ft_digestive_issues'],
 'digestive_disturbances_like_bloating_or_indigestion': ['ft_digestive_issues'],
 'digestive_disturbances_like_heartburn': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_disturbances_like_heartburn_or_loose_stools': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_disturbances_like_hyperacidity': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_disturbances_like_ibs': ['ft_digestive_issues'],
 'digestive_irregularities': ['ft_digestive_issues'],
 'digestive_issues': ['ft_digestive_issues'],
 'digestive_issues_like_acidity_or_bloating': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_issues_like_bloating': ['ft_digestive_issues'],
 'digestive_issues_like_bloating_and_constipation': ['ft_digestive_issues'],
 'digestive_issues_like_bloating_and_indigestion': ['ft_digestive_issues'],
 'digestive_issues_like_bloating_or_indigestion': ['ft_digestive_issues'],
 'digestive_issues_like_bloating_or_irregular_bowel_movements': ['ft_digestive_issues'],
 'digestive_issues_like_hyperacidity': ['ft_digestive_issues', 'ft_acid_reflux'],
 'digestive_sluggishness_kapha_imbalance': ['ft_digestive_issues', 'ft_dosha_imbalance'],
 'fatigue': ['ft_fatigue_low_energy'],
 'fatigue_and_low_energy': ['ft_fatigue_low_energy'],
 'fatigue_or_burnout': ['ft_fatigue_low_energy', 'ft_stress'],
 'fatty_liver': ['ft_fatty_liver', 'ft_metabolic_conditions'],
 'fatty_liver_accumulation_of_kapha_and_unhealthy_fats_can_affect_liver_function': ['ft_fatty_liver', 'ft_metabolic_conditions', 'ft_dosha_imbalance'],
 'fatty_liver_high_cholesterol_and_excess_fat_accumulation_can_impact_liver_function': ['ft_fatty_liver', 'ft_metabolic_conditions'],
 'frequent_colds': ['ft_immunity_issues', 'ft_respiratory_issues'],
 'gastrointestinal_issues_like_acidity_or_bloating': ['ft_digestive_issues', 'ft_acid_reflux'],
 'hair_fall': ['ft_skin_issues'],
 'heart_related_disease': ['ft_cardiac_disease', 'ft_cardiac_irregularity'],
 'high_cholesterol': ['ft_metabolic_conditions'],
 'hormonal_imbalance': ['ft_metabolic_conditions'],
 'hormonal_imbalances': ['ft_metabolic_conditions'],
 'hyperacidity': ['ft_acid_reflux', 'ft_digestive_issues'],
 'hypertension': ['ft_hypertension'],
 'hypertension_due_to_chronic_stress_and_pitta_imbalance': ['ft_hypertension', 'ft_stress', 'ft_dosha_imbalance'],
 'hypertension_pitta_aggravation': ['ft_hypertension', 'ft_dosha_imbalance'],
 'hypertension_pitta_imbalance': ['ft_hypertension', 'ft_dosha_imbalance'],
 'hypertension_pitta_vata_vikruti': ['ft_hypertension', 'ft_dosha_imbalance'],
 'hyperthyroidism': ['ft_thyroid_issues'],
 'hypothyroidism': ['ft_thyroid_issues'],
 'hypothyroidism_potential_consequence_of_kapha_imbalance_and_sluggish_metabolism': ['ft_thyroid_issues', 'ft_metabolic_conditions', 'ft_dosha_imbalance'],
 'increased_acidity_or_heartburn': ['ft_acid_reflux'],
 'increased_anxiety': ['ft_anxiety'],
 'increased_anxiety_or_irritability': ['ft_anxiety', 'ft_irritability'],
 'increased_anxiety_or_restlessness_if_vata_is_not_managed': ['ft_anxiety', 'ft_dosha_imbalance'],
 'increased_inflammation': ['ft_inflammation'],
 'increased_irritability_or_mood_swings': ['ft_irritability', 'ft_mental_health'],
 'increased_joint_pain_and_stiffness': ['ft_joint_issues', 'ft_inflammation'],
 'increased_mucus_and_congestion': ['ft_respiratory_issues'],
 'increased_pitta_aggravation_leading_to_inflammation': ['ft_inflammation', 'ft_dosha_imbalance'],
 'increased_respiratory_issues_like_congestion_and_cough': ['ft_respiratory_issues'],
 'increased_susceptibility_to_congestion_or_respiratory_issues': ['ft_respiratory_issues', 'ft_immunity_issues'],
 'indigestion': ['ft_digestive_issues'],
 'indigestion_and_bloating': ['ft_digestive_issues'],
 'indigestion_and_reduced_appetite': ['ft_digestive_issues', 'ft_appetite_issues'],
 'indigestion_due_to_irregular_digestive_fire': ['ft_digestive_issues', 'ft_dosha_imbalance'],
 'inflammatory_conditions': ['ft_inflammation'],
 'irregular_digestion': ['ft_digestive_issues'],
 'irritability': ['ft_irritability'],
 'joint_pain': ['ft_joint_issues'],
 'joint_pain_and_stiffness': ['ft_joint_issues'],
 'joint_pain_due_to_vata_aggravation': ['ft_joint_issues', 'ft_dosha_imbalance'],
 'joint_pain_or_stiffness': ['ft_joint_issues'],
 'joint_stiffness': ['ft_joint_issues'],
 'joint_stiffness_and_pain': ['ft_joint_issues'],
 'joint_stiffness_or_discomfort': ['ft_joint_issues'],
 'leaky_gut': ['ft_digestive_issues'],
 'migraine': ['ft_migraine', 'ft_neurological'],
 'migraine_pitta_vata_vikruti': ['ft_migraine', 'ft_dosha_imbalance'],
 'obesity': ['ft_obesity_weight'],
 'obesity_or_excess_fat': ['ft_obesity_weight'],
 'parkinson': ['ft_neurological'],
 'pcod_pcos': ['ft_metabolic_conditions', 'ft_pcod_pcos'],
 'possible_impact_on_mental_clarity_and_focus_due_to_persistent_hyperthinking_and_vata_imbalance': ['ft_mental_clarity', 'ft_anxiety', 'ft_dosha_imbalance'],
 'potential_for_increased_joint_pain_and_stiffness_if_vata_imbalance_is_not_managed': ['ft_joint_issues', 'ft_dosha_imbalance'],
 'potential_for_inflammation_related_issues': ['ft_inflammation'],
 'potential_for_weight_gain': ['ft_obesity_weight', 'ft_metabolic_conditions'],
 'risk_of_developing_digestive_issues_like_ibs_or_hyperacidity_if_pitta_also_becomes_aggravated': ['ft_digestive_issues', 'ft_acid_reflux', 'ft_dosha_imbalance'],
 'sinus_congestion': ['ft_respiratory_issues'],
 'skin_conditions_like_acne_or_inflammation': ['ft_skin_issues', 'ft_inflammation'],
 'skin_conditions_like_eczema_pitta_aggravation': ['ft_skin_issues', 'ft_dosha_imbalance'],
 'skin_conditions_such_as_acne_or_eczema': ['ft_skin_issues'],
 'skin_dryness': ['ft_skin_issues'],
 'skin_dryness_and_cracking': ['ft_skin_issues'],
 'skin_dryness_and_roughness': ['ft_skin_issues'],
 'skin_dryness_and_sensitivity': ['ft_skin_issues'],
 'skin_dryness_or_sensitivity': ['ft_skin_issues'],
 'skin_inflammation': ['ft_skin_issues', 'ft_inflammation'],
 'skin_inflammation_or_rashes_pitta_imbalance': ['ft_skin_issues', 'ft_dosha_imbalance', 'ft_inflammation'],
 'skin_issues': ['ft_skin_issues'],
 'skin_issues_e_g': ['ft_skin_issues'],
 'skin_issues_like_acne_or_dryness': ['ft_skin_issues'],
 'skin_issues_like_acne_or_inflammation': ['ft_skin_issues', 'ft_inflammation'],
 'skin_issues_like_acne_or_rashes': ['ft_skin_issues'],
 'skin_issues_like_acne_or_redness': ['ft_skin_issues'],
 'skin_issues_like_dryness_or_inflammation': ['ft_skin_issues', 'ft_inflammation'],
 'skin_issues_like_eczema_pitta_aggravation': ['ft_skin_issues', 'ft_dosha_imbalance'],
 'skin_related_issues': ['ft_skin_issues'],
 'skin_related_issues_acne': ['ft_skin_issues'],
 'skin_related_issues_dryness': ['ft_skin_issues'],
 'skin_related_issues_e_g': ['ft_skin_issues'],
 'skin_related_issues_like_acne_or_eczema': ['ft_skin_issues'],
 'skin_related_issues_like_acne_or_inflammation': ['ft_skin_issues', 'ft_inflammation'],
 'skin_related_issues_like_dryness_and_cracking': ['ft_skin_issues'],
 'skin_related_issues_like_dryness_and_inflammation': ['ft_skin_issues', 'ft_inflammation'],
 'skin_related_issues_like_dryness_or_dullness': ['ft_skin_issues'],
 'skin_related_issues_like_dryness_or_inflammation': ['ft_skin_issues', 'ft_inflammation'],
 'skin_related_issues_like_eczema_if_dryness_and_kapha_congestion_are_not_addressed': ['ft_skin_issues', 'ft_dosha_imbalance'],
 'skin_related_issues_pitta_vikruti': ['ft_skin_issues', 'ft_dosha_imbalance'],
 'sleep_disturbances': ['ft_sleep_issues'],
 'sleep_disturbances_and_anxiety': ['ft_sleep_issues', 'ft_anxiety'],
 'sleep_disturbances_due_to_mental_agitation': ['ft_sleep_issues', 'ft_anxiety'],
 'sleep_disturbances_due_to_overthinking': ['ft_sleep_issues', 'ft_anxiety'],
 'sleep_disturbances_or_anxiety': ['ft_sleep_issues', 'ft_anxiety'],
 'sleep_disturbances_or_insomnia': ['ft_sleep_issues'],
 'sleep_irregularities': ['ft_sleep_issues'],
 'sleep_issues': ['ft_sleep_issues'],
 'sleep_issues_due_to_high_hyperthinking_and_vata_imbalance': ['ft_sleep_issues', 'ft_anxiety', 'ft_dosha_imbalance'],
 'type_2_diabetes': ['ft_type_2_diabetes', 'ft_metabolic_conditions'],
 'type_2_diabetes_chronic_stress': ['ft_type_2_diabetes', 'ft_stress', 'ft_metabolic_conditions'],
 'type_2_diabetes_if_kapha_aggravating_diet_and_lifestyle_continue': ['ft_type_2_diabetes', 'ft_metabolic_conditions', 'ft_dosha_imbalance'],
 'weight_gain': ['ft_obesity_weight', 'ft_metabolic_conditions'],
 'weight_gain_and_sluggishness': ['ft_obesity_weight', 'ft_fatigue_low_energy'],
 'weight_gain_due_to_sluggish_metabolism': ['ft_obesity_weight', 'ft_metabolic_conditions'],
 'weight_gain_kapha_imbalance': ['ft_obesity_weight', 'ft_dosha_imbalance'],
 'weight_gain_or_accumulation_of_excess_kapha': ['ft_obesity_weight', 'ft_dosha_imbalance'],
 'weight_gain_or_sluggishness_if_kapha_imbalances_are_not_addressed': ['ft_obesity_weight', 'ft_metabolic_conditions', 'ft_dosha_imbalance'],
 'weight_loss': ['ft_weight_loss'],
 'while_your_current_immunity_is_high': ['ft_immunity_issues']
}

# %%
import pandas as pd

# --- Step 5: Collapse to canonical categories efficiently ---

# Add unique row id BEFORE melt
data = data.copy()  # avoids fragmentation warnings
data['_row'] = range(len(data))

# Melt the wide issue columns into long format
df_long = data.melt(
    id_vars=['_row', 'future_issues_list'], 
    value_vars=list(orig_to_canonical_ft.keys()),  # only mapped issue columns
    var_name='original', 
    value_name='flag'
)

# Keep only rows where the flag is 1 (issue present)
df_long = df_long[df_long['flag'] == 1].drop(columns='flag')

# Map each original issue to one or more canonical categories
df_long['canonical'] = df_long['original'].map(orig_to_canonical_ft)

# Explode because some originals map to multiple canonical categories
df_long = df_long.explode('canonical')

# --- Step 6: Build canonical one-hot columns with crosstab ---
df_flags = pd.crosstab(df_long['_row'], df_long['canonical'])

# Ensure all canonical names exist as columns (even if all 0)
all_canonicals = sorted({c for v in orig_to_canonical_ft.values() for c in v})
df_flags = df_flags.reindex(columns=all_canonicals, fill_value=0)

# --- Step 7: Drop raw one-hot issue columns ---
data = data.drop(columns=[c for c in all_future_issues if c in data.columns])

# Merge back canonical flags
data = data.join(df_flags.astype(int))

# --- Optional cleanup ---
data.drop(columns=['_row'], inplace=True)

# %%
data.columns.to_list()
# Out:
# ['user_id',
#  'full_name',
#  'phone_number',
#  'onboarding_date',
#  'onboarding_time',
#  'language',
#  'gender',
#  'date_of_birth',
#  'age',
#  'height',
#  'weight',
#  'bmi',
#  'prakruti',
#  'vikruti',
#  'pulse_rate',
#  'remark',
#  'rhythm',
#  'toxin_score',
#  'immunity_score',
#  'digestion_score',
#  'hyperthinking_score',
#  'stress_score',
#  'hydration_score',
#  'flexibility_score',
#  'possibleHealthIssuesCurrent',
#  'possibleHealthIssuesFuture',
#  'strongOrgans',
#  'weakOrgans',
#  'atRiskOrgans',
#  'age_group1',
#  'age_group2',
#  'bmi_category',
#  'age_group1_num',
#  'age_group2_num',
#  'bmi_category_num',
#  'issues_list',
#  'appetite_issues',
#  'cardiac_irregularity',
#  'dosha_imbalance',
#  'elevated_pulse',
#  'fatigue_low_energy',
#  'hydration_issues',
#  'immunity_issues',
#  'inflammation',
#  'joint_issues',
#  'metabolic_conditions',
#  'obesity_weight',
#  'respiratory_issues',
#  'stress',
#  'thyroid_issues',
# ...

# %%
import re

# Step 1: Extract just organ names
def extract_organs(cell):
    if pd.isna(cell):
        return []
    parts = [p.strip() for p in cell.split(",")]
    organs = [p for p in parts if " " not in p]  # keep only single words (no spaces)
    return organs

data["strong_organs_list"] = data["strongOrgans"].apply(extract_organs)

# Step 2: Clean for column naming
def clean_name(name):
    name = name.lower().strip()
    name = re.sub(r"[^0-9a-zA-Z]+", "_", name)   # replace non-alphanumeric
    name = re.sub(r"_+", "_", name).strip("_")   # collapse multiple _
    return name

# Step 3: Get all unique organ names
all_organs = sorted({clean_name(org) for row in data["strong_organs_list"] for org in row})

# Step 4: OHE encode
for organ in all_organs:
    data[f"strong_{organ}"] = data["strong_organs_list"].apply(
        lambda x: 1 if organ in [clean_name(o) for o in x] else 0
    )

# %%
data.columns.to_list()
# Out:
# ['user_id',
#  'full_name',
#  'phone_number',
#  'onboarding_date',
#  'onboarding_time',
#  'language',
#  'gender',
#  'date_of_birth',
#  'age',
#  'height',
#  'weight',
#  'bmi',
#  'prakruti',
#  'vikruti',
#  'pulse_rate',
#  'remark',
#  'rhythm',
#  'toxin_score',
#  'immunity_score',
#  'digestion_score',
#  'hyperthinking_score',
#  'stress_score',
#  'hydration_score',
#  'flexibility_score',
#  'possibleHealthIssuesCurrent',
#  'possibleHealthIssuesFuture',
#  'strongOrgans',
#  'weakOrgans',
#  'atRiskOrgans',
#  'age_group1',
#  'age_group2',
#  'bmi_category',
#  'age_group1_num',
#  'age_group2_num',
#  'bmi_category_num',
#  'issues_list',
#  'appetite_issues',
#  'cardiac_irregularity',
#  'dosha_imbalance',
#  'elevated_pulse',
#  'fatigue_low_energy',
#  'hydration_issues',
#  'immunity_issues',
#  'inflammation',
#  'joint_issues',
#  'metabolic_conditions',
#  'obesity_weight',
#  'respiratory_issues',
#  'stress',
#  'thyroid_issues',
# ...

# %%
data['strong_organs_list']
# Out:
# 0                                    []
# 1                                    []
# 2                                    []
# 3             [Heart, Lungs, Intestine]
# 4             [Heart, Intestine, Brain]
#                      ...
# 1176    [Liver, Intestine, Gallbladder]
# 1177         [Heart, Intestine, Kidney]
# 1178        [Stomach, Intestine, Heart]
# 1179          [Liver, Heart, Intestine]
# 1180         [Heart, Intestine, Kidney]
# Name: strong_organs_list, Length: 1181, dtype: object

# %%
import re

# Step 1: Extract just organ names
def extract_organs(cell):
    if pd.isna(cell):
        return []
    parts = [p.strip() for p in cell.split(",")]
    organs = [p for p in parts if " " not in p]  # keep only single words (no spaces)
    return organs

data["weak_organs_list"] = data["weakOrgans"].apply(extract_organs)

# Step 2: Clean for column naming
def clean_name(name):
    name = name.lower().strip()
    name = re.sub(r"[^0-9a-zA-Z]+", "_", name)   # replace non-alphanumeric
    name = re.sub(r"_+", "_", name).strip("_")   # collapse multiple _
    return name

# Step 3: Get all unique organ names
all_organs = sorted({clean_name(org) for row in data["weak_organs_list"] for org in row})

# Step 4: OHE encode
for organ in all_organs:
    data[f"weak_{organ}"] = data["weak_organs_list"].apply(
        lambda x: 1 if organ in [clean_name(o) for o in x] else 0
    )

# %%
import pandas as pd

# Save dataframe to Excel
output_file = "data_output10.xlsx"
data.to_excel(output_file, index=False)

print(f"Dataframe saved as {output_file}")
# Out:
# Dataframe saved as data_output10.xlsx
